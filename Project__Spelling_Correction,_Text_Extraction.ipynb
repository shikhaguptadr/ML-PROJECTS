# %% [markdown]
# <a href="https://colab.research.google.com/github/shikhaguptadr/ML-PROJECTS/blob/main/Project__Spelling_Correction%2C_Text_Extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Spelling Correction**

# %% [markdown]
# ### **Import the dependency**

# %%
# Import the dependency
from textblob import TextBlob

# enter incorrect text
incorrect_text = 'i am goood'

# %%
# Using textBlb library
textBlb = TextBlob(incorrect_text)

# %%
# Print correct string
textBlb.correct().string
# Out:
# 'i am good'

# %% [markdown]
# ## **Another way to do this**

# %%
! pip install pyspellchecker
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 93.6 MB/s eta 0:00:00
# ...

# %%
from spellchecker import SpellChecker

spell = SpellChecker()

text = "Data scienttist is a very goood career. you shoulld learne"

dict_of_autocorrect_words = {}
for i in spell.unknown(text.split()):
    dict_of_autocorrect_words[i] = spell.correction(i)

print(f'The AUTOCORRECT suggestions are Mis-spelled words are {dict_of_autocorrect_words}')

temp = text.split()
res = []
for wrd in temp:

    res.append(dict_of_autocorrect_words.get(wrd, wrd))

res = ' '.join(res)

print(res)
# Out:
# The AUTOCORRECT suggestions are Mis-spelled words are {'scienttist': 'scientist', 'goood': 'good', 'career.': 'career', 'learne': 'learn', 'shoulld': 'should'}
# Data scientist is a very good career you should learn

# %% [markdown]
# # **Text Extraction**

# %% [markdown]
# ### **Import the dependency**

# %%
# Import the dependency
# !pip install easyocr
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 63.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 15.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 963.8/963.8 kB 51.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.1/292.1 kB 23.5 MB/s eta 0:00:00
# ...

# %%
# Import the dependency
import matplotlib.pyplot as plt
import cv2
import easyocr
from pylab import rcParams
from IPython.display import Image
rcParams['figure.figsize'] = 8, 16

# %%
# Reading the Image
reader = easyocr.Reader(['en'])

img = '/content/Screenshot 2025-09-01 at 2.36.58 PM.png'

# Showing the image
Image(img)
# Out:
# WARNING:easyocr.easyocr:Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
# Reading the text from the Image
output = reader.readtext(img)
output
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# [([[np.int32(33), np.int32(11)],
#    [np.int32(52), np.int32(11)],
#    [np.int32(52), np.int32(35)],
#    [np.int32(33), np.int32(35)]],
#   '9',
#   np.float64(0.9948454625636667)),
#  ([[np.int32(92), np.int32(10)],
#    [np.int32(227), np.int32(10)],
#    [np.int32(227), np.int32(40)],
#    [np.int32(92), np.int32(40)]],
#   '16-EEE-23',
#   np.float64(0.710663652808309)),
#  ([[np.int32(336), np.int32(10)],
#    [np.int32(443), np.int32(10)],
#    [np.int32(443), np.int32(40)],
#    [np.int32(336), np.int32(40)]],
#   'KHUSHI',
#   np.float64(0.7709072604182923)),
#  ([[np.int32(566), np.int32(10)],
#    [np.int32(722), np.int32(10)],
#    [np.int32(722), np.int32(40)],
#    [np.int32(566), np.int32(40)]],
#   '1620804923',
# ...

# %%
# Text correction
text = ''
for i in range(len(output)):
  text =text +'\n'+ output[i][1]

print(text)
# Out:
# 9
# 16-EEE-23
# KHUSHI
# 1620804923
# 12
# 8
# 9
# 8
# 17
# 6
# 60
# 80.0
# 2
# 12
# 92.3
# 10
# 18-EEE-23 DIVYANSHU CHAURASIA
# 1820804923
# 7
# 5
# 6
# 3
# 9
# 3
# 33
# 44.0
# 3
# 7
# 53.8
# 11
# 22-EEE-23 SUNNY KUMAR THAKUR
# 2220804923
# 5
# 2
# 3
# 5
# 17
# 22.7
# 0
# 2
# 0
# 0
# 2
# 15.4
# 12
# 28-EEE-23
# KANAK
# 2820804923
# 7
# 2
# 4
# 4
# 8
# 4
# 29
# 38.7
# 0
# 2
# 2
# 0
# 4
# 30.8
# 13
# 29-EEE-23
# GAURAV KUMAR
# 2920804923
# 14
# 6
# 10
# 6
# 17
# 8
# 61
# 81.3
# 2
# 4
# 3
# 2
# 12
# 92.3
